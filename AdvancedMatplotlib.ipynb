# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
iris=pd.read_csv('iris.csv')
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'])

# %%
iris.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 101  102            5.8           2.7            5.1           1.9
# 112  113            6.8           3.0            5.5           2.1
# 104  105            6.5           3.0            5.8           2.2
# 32    33            5.2           4.1            1.5           0.1
# 73    74            6.1           2.8            4.7           1.2
#
#              Species
# 101   Iris-virginica
# 112   Iris-virginica
# 104   Iris-virginica
# 32       Iris-setosa
# 73   Iris-versicolor

# %%
iris['Species'] = iris['Species'].replace({'Iris-setosa': 0, 'Iris-virginica': 1, 'Iris-versicolor': 2})

# %%
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        1
# 146  147            6.3           2.5            5.0           1.9        1
# 147  148            6.5           3.0            5.2           2.0        1
# 148  149            6.2           3.4            5.4           2.3        1
# 149  150            5.9           3.0            5.1           1.8        1
#
# [150 rows x 6 columns]

# %%
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'])
plt.xlabel('Sepal Length')
plt.ylabel('Petal Lengeth')
plt.colorbar()

# %% [markdown]
# ### size of the graph

# %%
plt.figure(figsize=(10,5))
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'])
plt.xlabel('Sepal Length')
plt.ylabel('Petal Lengeth')
plt.colorbar()

# %% [markdown]
# ### Anotation

# %%
df=pd.read_csv('batter.csv')
df.head()
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577
# 3  RG Sharma  5881  30.314433   126.964594
# 4   SK Raina  5536  32.374269   132.535312

# %%
sample_df=df.head(100).sample(25,random_state=5)

# %%
plt.scatter(sample_df['avg'],sample_df['strike_rate'])

# %%
x=[1,2,3,4]
y=[5,7,9,4]
plt.scatter(x,y)
plt.text(1,5,'Point 1')
# Out:
# Text(1, 5, 'Point 1')

# %% [markdown]
# ### Giving text to each point on the graph

# %%
sample_df.head()
# Out:
#        batter  runs        avg  strike_rate
# 66  KH Pandya  1326  22.100000   132.203390
# 32   SE Marsh  2489  39.507937   130.109775
# 46  JP Duminy  2029  39.784314   120.773810
# 28   SA Yadav  2644  29.707865   134.009123
# 74  IK Pathan  1150  21.698113   116.751269

# %%
plt.figure(figsize=(15,7))
plt.scatter(sample_df['avg'],sample_df['strike_rate'],s=sample_df['runs'])

plt.axhline(130,color='red')

for i in range(sample_df.shape[0]):
    plt.text(sample_df['avg'].values[i],sample_df['strike_rate'].values[i],sample_df['batter'].values[i])

# %% [markdown]
# ### Subplots

# %%
df=pd.read_csv('batter.csv')

# %%
df.head()
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577
# 3  RG Sharma  5881  30.314433   126.964594
# 4   SK Raina  5536  32.374269   132.535312

# %%
plt.scatter(df['avg'],df['strike_rate'])

# %%
fig, ax=plt.subplots()
ax.scatter(df['avg'],df['strike_rate'])
ax.set_title('Something')
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
# Out:
# Text(0, 0.5, 'Y Label')

# %%
fig,ax=plt.subplots(2,1)

# %% [markdown]
# ### Plot multiple Graphs together side by side

# %%
fig,ax=plt.subplots(2,1,sharex=True,figsize=(10,6))
ax[0].scatter(df['avg'],df['runs'], color='red')
ax[1].scatter(df['avg'],df['strike_rate'])
ax[0].set_title('Runs vs Avg Graph')
ax[0].set_ylabel('Runs')
ax[1].set_title('Avg vs Strike rate')
ax[1].set_xlabel('Average')
ax[1].set_ylabel('Strike Rate')
# Out:
# Text(0, 0.5, 'Strike Rate')

# %%
fig,ax=plt.subplots(2,2,figsize=(10,6))

ax[0,0].scatter(df['avg'],df['runs'], color='red')

ax[0,1].scatter(df['avg'],df['strike_rate'])

# ax[0,0].set_title('Runs vs Avg Graph')
# ax[0,0].set_ylabel('Runs')

# ax[0,1].set_title('Avg vs Strike rate')
# ax[0,1].set_xlabel('Average')
# ax[0,1].set_ylabel('Strike Rate')

ax[1,0].hist(df['avg'],color='red')

ax[1,1].hist(df['runs'])

# ax[1,0].set_title('Avg ')

# ax[1,1].set_title('Runs ')
# Out:
# (array([499.,  40.,  19.,  19.,   9.,   6.,   4.,   4.,   3.,   2.]),
#  array([   0. ,  663.4, 1326.8, 1990.2, 2653.6, 3317. , 3980.4, 4643.8,
#         5307.2, 5970.6, 6634. ]),
#  <BarContainer object of 10 artists>)

# %%
fig=plt.figure()

ax1=fig.add_subplot(2,2,1)
ax1.scatter(df['avg'],df['runs'], color='red')

ax2=fig.add_subplot(2,2,2)
ax2.hist(df['avg'],color='red')

ax3=fig.add_subplot(2,2,3)
ax3.hist(df['runs'])
# Out:
# (array([499.,  40.,  19.,  19.,   9.,   6.,   4.,   4.,   3.,   2.]),
#  array([   0. ,  663.4, 1326.8, 1990.2, 2653.6, 3317. , 3980.4, 4643.8,
#         5307.2, 5970.6, 6634. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## 3D Plots

# %%
batters=pd.read_csv('batter.csv')
fig=plt.figure()
ax=plt.subplot(projection='3d')

ax.scatter3D(batters['runs'],batters['avg'],batters['strike_rate'])
ax.set_xlabel('Runs')
ax.set_ylabel('Average')
ax.set_zlabel('Strike_Rate')
# Out:
# Text(0.5, 0, 'Strike_Rate')

# %% [markdown]
# ### 3D Line plot

# %%
x=[0,1,5]
y=[0,10,13]
z=[0,13,20]

fig=plt.figure()

ax=plt.figure()
ax=plt.subplot(projection='3d')
ax.scatter3D(x,y,z,s=[100,100,100])  #s=marker sixe
ax.plot3D(x,y,z,color='red')    #3d line

# %% [markdown]
# ### 3D surface plot

# %%
x=np.linspace(-10,10,100)
y=np.linspace(-10,10,100)

# %%
xx,yy=np.meshgrid(x,y)
xx.shape
# Out:
# (100, 100)

# %%
z=xx**2+yy**2    #XX^2+YY^2

# %%
fig=plt.figure(figsize=(10,6))
ax=plt.subplot(projection='3d')
p=ax.plot_surface(xx,yy,z,cmap='viridis')
fig.colorbar(p)

# %%
z=np.sin(xx)+np.log(yy)
fig=plt.figure(figsize=(10,6))
ax=plt.subplot(projection='3d')
p=ax.plot_surface(xx,yy,z,cmap='viridis')
fig.colorbar(p)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_11636\2754515107.py:1: RuntimeWarning: invalid value encountered in log
#   z=np.sin(xx)+np.log(yy)

# %% [markdown]
# ### Converting 3d graph to 2d using contour

# %%
fig=plt.figure(figsize=(10,6))
ax=plt.subplot()
p=ax.contourf(xx,yy,z,cmap='viridis')
fig.colorbar(p)
